# %%
import numpy as np # numerical computing 
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt #visualization
import seaborn as sns #modern visualization
# %matplotlib inline
sns.set_style("darkgrid")
plt.rcParams['figure.figsize'] = (14, 8)

# %%
df = pd.read_csv('cricket\clean_data.csv')
df.set_index('ID',inplace=True)
df.head()
# Out:
# C:\Users\SAWON\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                 NAME    COUNTRY                  Full name  Born  Died  \
# ID
# 3931   Ted a'Beckett  Australia   Edward Lambert a'Beckett  1907  1989
# 3932  Claude Achurch  Australia    Claude Septimus Achurch  1896  1979
# 3933     Chris Adams  Australia  Christopher Patrick Adams  1977   NaN
# 3934       Ted Adams  Australia       Edward William Adams  1896  1977
# 3935   Francis Adams  Australia              Francis Adams  1835  1911
#
#                                             Major teams   Batting style  \
# ID
# 3931                         ['Australia,', 'Victoria']  Right-hand bat
# 3932                                    New South Wales  Right-hand bat
# ...

# %%
#print(df.COUNTRY.unique())
#sns.countplot(x='COUNTRY', data=df)
#plt.show()
test_players = df[(df['BATTING_Tests_Mat'] > 0) | (df['BOWLING_Tests_Mat'] > 0)]
#print(test_players.COUNTRY.unique())
df = pd.read_csv('cricket\clean_data.csv')

plt.figure(figsize=(15,10)) # this creates a figure 8 inch wide, 4 inch high
ax=sns.countplot('COUNTRY',data=test_players) 
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
#sns.countplot(x="Column", data=ds)
plt.title("Country-wise Total no of Test Players",fontsize=20,color='r')
plt.show()

#ax = sns.countplot(x="Column", data=ds)

#ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
#plt.tight_layout()
#plt.show()
# Out:
# C:\Users\SAWON\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
#test_player_details=dict()
#explode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')
#m=df.groupby(['COUNTRY'].unique())['BATTING_Tests_Mat'].sum()
#print(m)
#for c,m in zip(df.COUNTRY,m):
 #   test_player_details[c]=m
  #  print(c)
#for c,m in test_player_details.items():
 #       print(c,m)
#fig1, ax1 = plt.subplots()
#ax1.pie(test_players.BATTING_Tests_Mat, labels=test_players.COUNTRY, autopct='%1.1f%%',
  #      shadow=True, startangle=90)
#ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

#plt.show()

# %%
odi_players = df[(df['BATTING_ODIs_Mat'] > 0) | (df['BOWLING_ODIs_Mat'] > 0)]
#print(test_players.COUNTRY.unique())
df = pd.read_csv('cricket\clean_data.csv')

plt.figure(figsize=(15,10)) # this creates a figure 8 inch wide, 4 inch high
ax=sns.countplot('COUNTRY',data=odi_players) 
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
#sns.countplot(x="Column", data=ds)
plt.title("Country-wise Total no of ODI Players",fontsize=20,color='r')
plt.show()

# %%
t20i_players = df[(df['BATTING_T20Is_Mat'] > 0) | (df['BOWLING_T20Is_Mat'] > 0)]
#print(test_players.COUNTRY.unique())
df = pd.read_csv('cricket\clean_data.csv')

plt.figure(figsize=(15,10)) # this creates a figure 8 inch wide, 4 inch high
ax=sns.countplot('COUNTRY',data=t20i_players) 
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
#sns.countplot(x="Column", data=ds)
plt.title("Country-wise Total no of T20I Players",fontsize=20,color='r')
plt.show()

# %%
test_top_scorers = df[(df['BATTING_Tests_Runs'] >= 10000)]
df = pd.read_csv('cricket\clean_data.csv')
#print(test_top_scorers.BATTING_Tests_Runs)
plt.figure(figsize=(15,10)) # this creates a figure 8 inch wide, 4 inch high
ax=sns.barplot(x='NAME',y='BATTING_Tests_Runs',data=test_top_scorers) 
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
#sns.countplot(x="Column", data=ds)
#plt.yticks(np.arange(10000,15000,step=1000))
plt.title("Top scorers in Test Cricket",fontsize=20,color='r')
plt.show()
# Out:
# C:\Users\SAWON\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
odi_top_scorers = df[(df['BATTING_ODIs_Runs'] >= 10000)]
df = pd.read_csv('cricket\clean_data.csv')
#print(odi_top_scorers.BATTING_ODIs_Runs)
plt.figure(figsize=(20,10)) # this creates a figure 8 inch wide, 4 inch high
ax=sns.barplot(x='NAME',y='BATTING_ODIs_Runs',data=odi_top_scorers) 
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
#sns.countplot(x="Column", data=ds)
#plt.yticks(np.arange(10000,15000,step=1000))
plt.title("Top scorers in ODI Cricket",fontsize=20,color='r')
plt.show()
# Out:
# C:\Users\SAWON\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
tti_top_scorers = df[(df['BATTING_T20Is_Runs'] >= 2000)]
df = pd.read_csv('cricket\clean_data.csv')
#print(odi_top_scorers.BATTING_ODIs_Runs)
plt.figure(figsize=(20,10)) # this creates a figure 8 inch wide, 4 inch high
ax=sns.barplot(x='NAME',y='BATTING_T20Is_Runs',data=tti_top_scorers) 
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
#sns.countplot(x="Column", data=ds)
#plt.yticks(np.arange(10000,15000,step=1000))
plt.title("Top scorers in T20I Cricket",fontsize=20,color='r')
plt.show()
# Out:
# C:\Users\SAWON\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# # TEST_CRICKET_STATS

# %%
test_top_ave = df[(df['BATTING_Tests_Ave'] >= 50) & (df['BATTING_Tests_Mat']>=15)]
df = pd.read_csv('cricket\clean_data.csv')
#print(test_top_scorers.BATTING_Tests_Runs)
plt.figure(figsize=(15,10)) # this creates a figure 8 inch wide, 4 inch high
ax=sns.barplot(x='NAME',y='BATTING_Tests_Ave',data=test_top_ave) 
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
#sns.countplot(x="Column", data=ds)
#plt.yticks(np.arange(10000,15000,step=1000))
plt.title("Top Batting Average in Test Cricket",fontsize=20,color='r')
plt.show()
# Out:
# C:\Users\SAWON\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
print("Player: "+df.NAME[df['BATTING_Tests_100'].idxmax()])
print("Most Hundreds in Tests: "+str(df['BATTING_Tests_100'].max()))
#most 5 wicket haul
# Out:
# Player: Sachin Tendulkar
# Most Hundreds in Tests: 51.0

# %%
print("Player: "+df.NAME[df['BATTING_Tests_Runs'].idxmax()])
print("Most Runs in Tests: "+str(df['BATTING_Tests_Runs'].max()))
#most 5 wicket haul
# Out:
# Player: Sachin Tendulkar
# Most Runs in Tests: 15921.0

# %%
print("Player: "+df.NAME[df['BOWLING_Tests_Wkts'].idxmax()])
print("Most Wickets in Tests: "+str(df['BOWLING_Tests_Wkts'].max()))
#most 5 wicket haul
# Out:
# Player: Muttiah Muralitharan
# Most Wickets in Tests: 800.0

# %%
print("Player: "+df.NAME[df['BOWLING_Tests_10'].idxmax()])
print("Most 10w in Tests: "+str(df['BOWLING_Tests_10'].max()))
#most 5 wicket haul
# Out:
# Player: Muttiah Muralitharan
# Most 10w in Tests: 22.0

# %%
print("Player: "+df.NAME[df['BOWLING_Tests_5w'].idxmax()])
print("Most 5w in Tests: "+str(df['BOWLING_Tests_5w'].max()))
#most 5 wicket haul
# Out:
# Player: Muttiah Muralitharan
# Most 5w in Tests: 67.0

# %%
test_100s = df[(df['BATTING_Tests_100'] >= 30) & (df['BATTING_Tests_Mat']>=15)]
df = pd.read_csv('cricket\clean_data.csv')
#print(test_top_scorers.BATTING_Tests_Runs)
plt.figure(figsize=(15,10)) # this creates a figure 8 inch wide, 4 inch high
ax=sns.barplot(x='NAME',y='BATTING_Tests_100',data=test_100s) 
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
#sns.countplot(x="Column", data=ds)
#plt.yticks(np.arange(10000,15000,step=1000))
plt.title("Most no of Hundreds in Test Cricket",fontsize=20,color='r')
plt.show()
# Out:
# C:\Users\SAWON\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
test_top_ave = df[(df['BOWLING_Tests_Ave'] <= 28) & (df['BOWLING_Tests_Ave'] > 0) & (df['BOWLING_Tests_Balls']>=2500)]
df = pd.read_csv('cricket\clean_data.csv')
#print(test_top_scorers.BATTING_Tests_Runs)
plt.figure(figsize=(15,10)) # this creates a figure 8 inch wide, 4 inch high
ax=sns.swarmplot(x='COUNTRY',y='BOWLING_Tests_Ave',data=test_top_ave) 
ax.set_xticklabels(ax.get_xticklabels(), rotation=20, ha="right")
#sns.countplot(x="Column", data=ds)
#plt.yticks(np.arange(10000,15000,step=1000))
plt.title("Top Bowling Average in Test Cricket",fontsize=20,color='r')
plt.show()

# %%
test_top_5w = df[(df['BOWLING_Tests_5w'] >= 20)]
df = pd.read_csv('cricket\clean_data.csv')
#print(test_top_scorers.BATTING_Tests_Runs)
plt.figure(figsize=(15,10)) # this creates a figure 8 inch wide, 4 inch high
ax=sns.swarmplot(x='NAME',y='BOWLING_Tests_5w',data=test_top_5w,hue='COUNTRY') 
ax.set_xticklabels(ax.get_xticklabels(), rotation=20, ha="right")
#sns.countplot(x="Column", data=ds)
#plt.yticks(np.arange(10000,15000,step=1000))
plt.title("Most 5wicket haul in Test Cricket",fontsize=20,color='r')
plt.show()

# %%
test_top_10w = df[(df['BOWLING_Tests_10'] >= 5)]
df = pd.read_csv('cricket\clean_data.csv')
#print(test_top_scorers.BATTING_Tests_Runs)
plt.figure(figsize=(15,10)) # this creates a figure 8 inch wide, 4 inch high
ax=sns.swarmplot(x='NAME',y='BOWLING_Tests_10',data=test_top_10w,hue='COUNTRY') 
ax.set_xticklabels(ax.get_xticklabels(), rotation=20, ha="right")
#sns.countplot(x="Column", data=ds)
#plt.yticks(np.arange(10000,15000,step=1000))
plt.title("Most 10wicket haul in Test Cricket",fontsize=20,color='r')
plt.show()

# %% [markdown]
# # ODI STATS

# %%
print("Player: "+df.NAME[df['BATTING_ODIs_100'].idxmax()])
print("Most 100s in ODI: "+str(df['BATTING_ODIs_100'].max()))

#(most test centuries)
# Out:
# Player: Sachin Tendulkar
# Most 100s in ODI: 49.0

# %%
print("Player: "+df.NAME[df['BATTING_ODIs_Runs'].idxmax()])
print("Most Runs in ODI: "+str(df['BATTING_ODIs_Runs'].max()))
      #(most test centuries)
# Out:
# Player: Sachin Tendulkar
# Most Runs in ODI: 18426.0

# %%
print("Player:"+df.NAME[df['BOWLING_ODIs_Wkts'].idxmax()])
print("Most Wickets in ODI: "+str(df['BOWLING_ODIs_Wkts'].max()))      
#(most test centuries)
# Out:
# Player:Muttiah Muralitharan
# Most Wickets in ODI: 534.0

# %%
print("Player:"+df.NAME[df['BOWLING_ODIs_5w'].idxmax()])
print("Most 5w in ODI: "+str(df['BOWLING_ODIs_5w'].max()))
#(most test centuries)
# Out:
# Player:Waqar Younis
# Most 5w in ODI: 13.0

# %%
odi_top_ave = df[(df['BATTING_ODIs_Ave'] >= 45) & (df['BATTING_ODIs_Mat']>=50)]
df = pd.read_csv('cricket\clean_data.csv')
#print(test_top_scorers.BATTING_Tests_Runs)
plt.figure(figsize=(15,10)) # this creates a figure 8 inch wide, 4 inch high
ax=sns.barplot(x='NAME',y='BATTING_ODIs_Ave',data=odi_top_ave) 
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
#sns.countplot(x="Column", data=ds)
#plt.yticks(np.arange(10000,15000,step=1000))
plt.title("Top Batting Average in ODI Cricket",fontsize=20,color='r')
plt.show()
# Out:
# C:\Users\SAWON\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
odi_100s = df[(df['BATTING_ODIs_100'] >= 25) & (df['BATTING_ODIs_Mat']>=15)]
df = pd.read_csv('cricket\clean_data.csv')
#print(test_top_scorers.BATTING_Tests_Runs)
plt.figure(figsize=(15,10)) # this creates a figure 8 inch wide, 4 inch high
ax=sns.barplot(x='NAME',y='BATTING_ODIs_100',data=odi_100s) 
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
#sns.countplot(x="Column", data=ds)
#plt.yticks(np.arange(10000,15000,step=1000))
plt.title("Most no of Hundreds in ODI Cricket",fontsize=20,color='r')
plt.show()

# %%
odi_top_5w = df[(df['BOWLING_ODIs_5w'] >= 5)]
df = pd.read_csv('cricket\clean_data.csv')
#print(test_top_scorers.BATTING_Tests_Runs)
plt.figure(figsize=(15,10)) # this creates a figure 8 inch wide, 4 inch high
ax=sns.swarmplot(x='NAME',y='BOWLING_ODIs_5w',data=odi_top_5w,hue='COUNTRY') 
ax.set_xticklabels(ax.get_xticklabels(), rotation=20, ha="right")
#sns.countplot(x="Column", data=ds)
#plt.yticks(np.arange(10000,15000,step=1000))
plt.title("Most 5wicket haul in Odi Cricket",fontsize=20,color='r')
plt.show()
# Out:
# C:\Users\SAWON\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
odi_top_ave = df[(df['BOWLING_ODIs_Ave'] <= 30) & (df['BOWLING_ODIs_Ave']>0) & (df['BOWLING_ODIs_Mat']>60)]
df = pd.read_csv('cricket\clean_data.csv')
#print(test_top_scorers.BATTING_Tests_Runs)
plt.figure(figsize=(15,10)) # this creates a figure 8 inch wide, 4 inch high
ax=sns.swarmplot(x='COUNTRY',y='BOWLING_ODIs_Ave',data=odi_top_ave) 
ax.set_xticklabels(ax.get_xticklabels(), rotation=60, ha="right")
#sns.countplot(x="Column", data=ds)
#plt.yticks(np.arange(10000,15000,step=1000))
plt.title("Top Bowling Average in ODI Cricket",fontsize=20,color='r')
plt.show()
# Out:
# C:\Users\SAWON\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# # T20I STATS

# %%
tti_top_ave = df[(df['BATTING_T20Is_Ave'] >=30 ) & (df['BATTING_T20Is_SR']>=135) & (df['BATTING_T20Is_Mat'] >=20 )]
df = pd.read_csv('cricket\clean_data.csv')
dan=[]
#print(test_top_scorers.BATTING_Tests_Runs)
plt.figure(figsize=(15,10)) # this creates a figure 8 inch wide, 4 inch high
ax=sns.barplot(x='NAME',y=df['BATTING_T20Is_Ave'],data=tti_top_ave) 
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
#sns.countplot(x="Column", data=ds)
#plt.yticks(np.arange(10000,15000,step=1000))
plt.title("Match winners in T20I Cricket",fontsize=20,color='r')
plt.show()
# Out:
# C:\Users\SAWON\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
tti_top_sr = df[(df['BATTING_T20Is_SR'] >=140 ) & (df['BATTING_T20Is_BF'] >=500 )]
df = pd.read_csv('cricket\clean_data.csv')
dan=[]
#print(test_top_scorers.BATTING_Tests_Runs)
plt.figure(figsize=(15,10)) # this creates a figure 8 inch wide, 4 inch high
ax=sns.barplot(x='NAME',y=df['BATTING_T20Is_SR'],data=tti_top_sr) 
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
#sns.countplot(x="Column", data=ds)
#plt.yticks(np.arange(10000,15000,step=1000))
plt.title("Destructive Batsman in T20I Cricket",fontsize=20,color='r')
plt.show()

# %%
print("Player: "+df.NAME[df['BATTING_T20Is_50'].idxmax()])

print("Most no Of Fifities in T20IS:"+str(df['BATTING_T20Is_50'].max()))
#print(t20_highest_50)
# Out:
# Player: Suzie Bates
# Most no Of Fifities in T20IS:21.0

# %%
print("Player: "+df.NAME[df['BATTING_T20Is_4s'].idxmax()])
print("Most fours in T20i: "+str(df['BATTING_T20Is_4s'].max()))
#print(t20_highest_fours)
# Out:
# Player: Suzie Bates
# Most fours in T20i347.0

# %%
print("Player:"+df.NAME[df['BATTING_T20Is_6s'].idxmax()])
print("Most fours in T20i: "+str(df['BATTING_T20Is_6s'].max()))
#print(t20_highest_fours)
# Out:
# Player:Chris Gayle
# Most fours in T20i: 105.0

# %%
print("Player: "+df.NAME[df['BOWLING_T20Is_4w'].idxmax()])
print("Most no Of 4W haul in T20IS:"+str(df['BOWLING_T20Is_4w'].max()))
#print(highest 4w+ haul in t20i)
# Out:
# Player: Saeed Ajmal
# Most no Of 4W haul in T20IS:4.0

# %%
print("Player: "+df.NAME[df['BOWLING_T20Is_5w'].idxmax()])
print("Most no Of 5W haul in T20IS:"+str(int(df['BOWLING_T20Is_5w'].max())))
#print(highest 5w haul in t20 i)
# Out:
# Player: Anisa Mohammed
# Most no Of 5W haul in T20IS:3

# %%
tti_top_ave = df[(df['BOWLING_T20Is_Ave'] <= 30) & (df['BOWLING_T20Is_Ave']>0) & (df['BOWLING_T20Is_Mat']>20)]
df = pd.read_csv('cricket\clean_data.csv')
plt.figure(figsize=(15,10)) # this creates a figure 8 inch wide, 4 inch high
ax=sns.swarmplot(x='COUNTRY',y='BOWLING_T20Is_Ave',data=tti_top_ave) 
ax.set_xticklabels(ax.get_xticklabels(), rotation=60, ha="right")
#sns.countplot(x="Column", data=ds)
#plt.yticks(np.arange(10000,15000,step=1000))
plt.title("Top Bowling Average in T20I Cricket Country wise",fontsize=20,color='r')
plt.show()

# %%
tti_top_eco = df[(df['BOWLING_T20Is_Econ'] <= 7) & (df['BOWLING_T20Is_Econ']>0) & (df['BOWLING_T20Is_Balls']>500)]
df = pd.read_csv('cricket\clean_data.csv')
#print(test_top_scorers.BATTING_Tests_Runs)
plt.figure(figsize=(15,10)) # this creates a figure 8 inch wide, 4 inch high
ax=sns.swarmplot(x='COUNTRY',y='BOWLING_T20Is_Econ',data=tti_top_eco) 
ax.set_xticklabels(ax.get_xticklabels(), rotation=60, ha="right")
#sns.countplot(x="Column", data=ds)
#plt.yticks(np.arange(10000,15000,step=1000))
plt.title("Lowest Economy in T20I Cricket",fontsize=20,color='r')
plt.show()

# %% [markdown]
# # FIRST_CLASS

# %%
print("Player:"+df.NAME[df['BATTING_First-class_Runs'].idxmax()])
print("Most Runs in First class cricket:"+str(df['BATTING_First-class_Runs'].max()))
print("Player:"+df['Major teams'][df['BATTING_First-class_Runs'].idxmax()])
#print(first class batsman)
# Out:
# Player:Sir Jack Hobbs
# Most Runs in First class cricket:61760.0
# Player:['England,', "Maharaj Kumar of Vizianagram's XI,", 'Surrey']

# %%
print("Player:"+df.NAME[df['BOWLING_First-class_Wkts'].idxmax()])
print("Most wickets in First class cricket:"+str(df['BOWLING_First-class_Wkts'].max()))
print("Player:"+df['Major teams'][df['BOWLING_First-class_Wkts'].idxmax()])
#print(first class bowler)
# Out:
# Player:Wilfred Rhodes
# Most wickets in First class cricket:4204.0
# Player:['England,', 'Europeans (India),', "Maharaja of Patiala's XI,", 'Yorkshire']

# %%
fc_top_ave = df[(df['BATTING_First-class_Ave'] >= 45) & (df['BATTING_First-class_Mat']>=40) & (df['BATTING_Tests_Mat']==0)]
df = pd.read_csv('cricket\clean_data.csv')
#print(test_top_scorers.BATTING_Tests_Runs)
plt.figure(figsize=(20,20)) # this creates a figure 8 inch wide, 4 inch high
ax=sns.barplot(x='BATTING_First-class_Ave',y='NAME',data=fc_top_ave) 
ax.set_xticklabels(ax.get_xticklabels(), rotation=80, ha="right")
#sns.countplot(x="Column", data=ds)
#plt.yticks(np.arange(10000,15000,step=1000))
plt.title("Top Batting Average in First Class Cricket",fontsize=20,color='r')
plt.show()
# Out:
# C:\Users\SAWON\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
fc_top_200 = df[(df['BATTING_First-class_100'] >= 30) & (df['BATTING_Tests_Mat']==0)]
df = pd.read_csv('cricket\clean_data.csv')
#print(test_top_scorers.BATTING_Tests_Runs)
plt.figure(figsize=(20,20)) # this creates a figure 8 inch wide, 4 inch high
ax=sns.barplot(x='BATTING_First-class_100',y='NAME',data=fc_top_200) 
ax.set_xticklabels(ax.get_xticklabels(), rotation=80, ha="right")
#sns.countplot(x="Column", data=ds)
#plt.yticks(np.arange(10000,15000,step=1000))
plt.title("Top 100 getters in First Class Cricket",fontsize=20,color='r')
plt.show()
# Out:
# C:\Users\SAWON\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
fc_top_ave = df[(df['BOWLING_First-class_Ave']>0) &(df['BOWLING_First-class_Ave'] <= 20) & (df['BOWLING_First-class_Balls']>6000) & (df['BOWLING_Tests_Mat']==0)]
df = pd.read_csv('cricket\clean_data.csv')
#print(test_top_scorers.BATTING_Tests_Runs)
plt.figure(figsize=(20,10)) # this creates a figure 8 inch wide, 4 inch high
ax=sns.swarmplot(y='BOWLING_First-class_Ave',x='NAME',data=fc_top_ave,hue="COUNTRY") 
ax.set_xticklabels(ax.get_xticklabels(), rotation=80, ha="right")
#sns.countplot(x="Column", data=ds)
#plt.yticks(np.arange(10000,15000,step=1000))
plt.title("Top Bowling Average in First Class Cricket",fontsize=20,color='r')
plt.show()

# %%
fc_top_10w = df[(df['BOWLING_First-class_10']>10) & (df['BOWLING_Tests_Mat']==0)]
df = pd.read_csv('cricket\clean_data.csv')
#print(test_top_scorers.BATTING_Tests_Runs)
plt.figure(figsize=(20,10)) # this creates a figure 8 inch wide, 4 inch high
ax=sns.scatterplot(y='BOWLING_First-class_10',x='NAME',data=fc_top_10w,hue="COUNTRY") 
ax.set_xticklabels(ax.get_xticklabels(), rotation=80, ha="right")
#sns.countplot(x="Column", data=ds)
#plt.yticks(np.arange(10000,15000,step=1000))
plt.title("Top 10w Haul in First Class Cricket",fontsize=20,color='r')
plt.show()

# %% [markdown]
# # LIST_A_STATS

# %%
print("Player:"+df.NAME[df['BATTING_List A_Runs'].idxmax()])
#print(t20_highest_50)
print("Most Runs in List A cricket:"+str(df['BATTING_List A_Runs'].max()))
print("Player:"+df['Major teams'][df['BATTING_List A_Runs'].idxmax()])
#print(first class batsman)
# Out:
# Player:Graham Gooch
# Most Runs in List A cricket:22211.0
# Player:['England,', 'Essex,', 'Western Province']

# %%
print("Player:"+df.NAME[df['BOWLING_List A_Wkts'].idxmax()])
#print(List A Batsman with most wickets)
print("Most Runs in List A cricket:"+str(df['BOWLING_List A_Wkts'].max()))
print("Player:"+df['Major teams'][df['BOWLING_List A_Wkts'].idxmax()])
#print(List A Bowler with most wickets)
# Out:
# Player:Wasim Akram
# Most Runs in List A cricket:881.0
# Player:['Pakistan,', 'Hampshire,', 'Lahore,', 'Lancashire,', 'Pakistan Automobiles Corporation,', 'Pakistan International Airlines']

# %% [markdown]
# # T20 STATS

# %%
tti_top_ave = df[(df['BATTING_T20s_Ave'] >=30 ) & (df['BATTING_T20s_SR']>=135) & (df['BATTING_T20s_Mat'] >=20 )]
df = pd.read_csv('cricket\clean_data.csv')
dan=[]
#print(test_top_scorers.BATTING_Tests_Runs)
plt.figure(figsize=(15,10)) # this creates a figure 8 inch wide, 4 inch high
ax=sns.barplot(x='NAME',y=df['BATTING_T20s_Ave'],data=tti_top_ave) 
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
#sns.countplot(x="Column", data=ds)
#plt.yticks(np.arange(10000,15000,step=1000))
plt.title("Match winners in T20 Cricket",fontsize=20,color='r')
plt.show()
# Out:
# C:\Users\SAWON\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
tti_top_sr = df[(df['BATTING_T20s_SR'] >=140 ) & (df['BATTING_T20s_BF'] >=500 )]
df = pd.read_csv('cricket\clean_data.csv')
dan=[]
#print(test_top_scorers.BATTING_Tests_Runs)
plt.figure(figsize=(15,15)) # this creates a figure 8 inch wide, 4 inch high
ax=sns.barplot(y='NAME',x=df['BATTING_T20s_SR'],data=tti_top_sr) 
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
#sns.countplot(x="Column", data=ds)
#plt.yticks(np.arange(10000,15000,step=1000))
plt.title("Destructive Batsman in T20 Cricket",fontsize=20,color='r')
plt.show()
# Out:
# C:\Users\SAWON\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
print("Player: "+df.NAME[df['BATTING_T20s_50'].idxmax()])

print("Most no Of Fifities in T20S:"+str(df['BATTING_T20s_50'].max()))
#print(t20_highest_50)
# Out:
# Player: Chris Gayle
# Most no Of Fifities in T20S:76.0

# %%
print("Player: "+df.NAME[df['BATTING_T20s_4s'].idxmax()])
print("Most fours in T20: "+str(df['BATTING_T20s_4s'].max()))
#print(t20_highest_fours)
# Out:
# Player: Chris Gayle
# Most fours in T20: 942.0

# %%
print("Player:"+df.NAME[df['BATTING_T20s_6s'].idxmax()])
print("Most fours in T20: "+str(df['BATTING_T20s_6s'].max()))
#print(t20_highest_fours)
# Out:
# Player:Chris Gayle
# Most fours in T20: 907.0

# %%
print("Player: "+df.NAME[df['BOWLING_T20s_4w'].idxmax()])
print("Most no Of 4W haul in T20S:"+str(df['BOWLING_T20s_4w'].max()))
#print(highest 4w+ haul in t20)
# Out:
# Player: Sunil Narine
# Most no Of 4W haul in T20S:11.0

# %%
print("Player: "+df.NAME[df['BOWLING_T20s_5w'].idxmax()])
print("Most no Of 5W haul in T20S:"+str(int(df['BOWLING_T20s_5w'].max())))
#print(highest 5w haul in t20 )
# Out:
# Player: Lasith Malinga
# Most no Of 5W haul in T20S:4

# %%
tti_top_ave = df[(df['BOWLING_T20s_Ave'] <= 30) & (df['BOWLING_T20s_Ave']>0) & (df['BOWLING_T20s_Mat']>20)]
df = pd.read_csv('cricket\clean_data.csv')
plt.figure(figsize=(15,10)) # this creates a figure 8 inch wide, 4 inch high
ax=sns.swarmplot(x='COUNTRY',y='BOWLING_T20s_Ave',data=tti_top_ave) 
ax.set_xticklabels(ax.get_xticklabels(), rotation=60, ha="right")
#sns.countplot(x="Column", data=ds)
#plt.yticks(np.arange(10000,15000,step=1000))
plt.title("Top Bowling Average in T20 Cricket Country Wise",fontsize=20,color='r')
plt.show()

# %%
tti_top_eco = df[(df['BOWLING_T20s_Econ'] <= 7) & (df['BOWLING_T20s_Econ']>0) & (df['BOWLING_T20s_Balls']>500)]
df = pd.read_csv('cricket\clean_data.csv')
#print(test_top_scorers.BATTING_Tests_Runs)
plt.figure(figsize=(15,10)) # this creates a figure 8 inch wide, 4 inch high
ax=sns.swarmplot(x='COUNTRY',y='BOWLING_T20s_Econ',data=tti_top_eco) 
ax.set_xticklabels(ax.get_xticklabels(), rotation=60, ha="right")
#sns.countplot(x="Column", data=ds)
#plt.yticks(np.arange(10000,15000,step=1000))
plt.title("Lowest Economy in T20 Cricket",fontsize=20,color='r')
plt.show()
# Out:
# C:\Users\SAWON\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
